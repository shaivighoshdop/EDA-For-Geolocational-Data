# %% [markdown]
# <a href="https://colab.research.google.com/github/shaivighoshdop/EDA-For-Geolocational-Data/blob/main/EDA_on_Geolocational_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploratory Analysis of Geolocational Data

# %% [markdown]
# ## Data Collection

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/shaivighoshdop/EDA-For-Geolocational-Data/main/food_coded.csv'
data = pd.read_csv(url)
# Dataset is now stored in a Pandas Dataframe

# %%
data
# Out:
#        GPA  Gender  ...  waffle_calories                    weight
# 0      2.4       2  ...             1315                       187
# 1    3.654       1  ...              900                       155
# 2      3.3       1  ...              900  I'm not answering this.
# 3      3.2       1  ...             1315             Not sure, 240
# 4      3.5       1  ...              760                       190
# ..     ...     ...  ...              ...                       ...
# 120    3.5       1  ...             1315                       156
# 121      3       1  ...             1315                       180
# 122  3.882       1  ...             1315                       120
# 123      3       2  ...             1315                       135
# 124    3.9       1  ...              575                       135
#
# [125 rows x 61 columns]

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# The process of Extracting the features, (and dealing with different kinds of values as well as NaN values) is known as Data Cleaning.

# %%
data.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
#        'persian_food', 'self_perception_weight', 'soup', 'sports', 'thai_food',
#        'tortilla_calories', 'turkey_calories', 'type_sports', 'veggies_day',
#        'vitamins', 'waffle_calories', 'weight'],
#       dtype='object')

# %%
column=['cook','eating_out','employment','ethnic_food', 'exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']

# %%
d=data[column]

# %%
d
# Out:
#      cook  eating_out  employment  ...  pay_meal_out  sports  veggies_day
# 0     2.0           3         3.0  ...             2     1.0            5
# 1     3.0           2         2.0  ...             4     1.0            4
# 2     1.0           2         3.0  ...             3     2.0            5
# 3     2.0           2         3.0  ...             2     2.0            3
# 4     1.0           2         2.0  ...             4     1.0            4
# ..    ...         ...         ...  ...           ...     ...          ...
# 120   3.0           2         1.0  ...             4     1.0            5
# 121   3.0           4         3.0  ...             4     NaN            5
# 122   3.0           3         3.0  ...             4     2.0            4
# 123   3.0           5         2.0  ...             3     2.0            3
# 124   NaN           1         2.0  ...             3     2.0            4
#
# [125 rows x 11 columns]

# %% [markdown]
# ## Data Exploration and Visualisation

# %%
import seaborn as sns
sns.pairplot(d)

# %% [markdown]
# #Boxplot of Dataset

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
% matplotlib inline 
ax=d.boxplot(figsize=(18,8))
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# [Text(0, 0, 'cook'),
#  Text(0, 0, 'eating_out'),
#  Text(0, 0, 'employment'),
#  Text(0, 0, 'ethnic_food'),
#  Text(0, 0, 'exercise'),
#  Text(0, 0, 'fruit_day'),
#  Text(0, 0, 'income'),
#  Text(0, 0, 'on_off_campus'),
#  Text(0, 0, 'pay_meal_out'),
#  Text(0, 0, 'sports'),
#  Text(0, 0, 'veggies_day')]

# %%
d.shape
# Out:
# (125, 11)

# %%
s=d.dropna()

# %% [markdown]
# ## Run KMeans Clustering on the data

# %%
# !pip install minisom
# Out:
# Collecting minisom
#   Downloading MiniSom-2.2.9.tar.gz (8.1 kB)
# Building wheels for collected packages: minisom
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.2.9-py3-none-any.whl size=8595 sha256=64cda4e4b157a4083e66180eb0e9b550e73c351a6885bec38455b2e449dc1e73
#   Stored in directory: /root/.cache/pip/wheels/3d/a1/10/f50b6f4865652eac239a2700de411c3078c27e1318320e494c
# Successfully built minisom
# Installing collected packages: minisom
# Successfully installed minisom-2.2.9

# %%
## for data
import numpy as np
import pandas as pd
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for geospatial
import folium
import geopy
## for machine learning
from sklearn import preprocessing, cluster
import scipy
## for deep learning
import minisom

# %%
f=['cook','income']
X = s[f]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i 
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()

# %% [markdown]
# ## Get Geolocational Data

# %%
from pandas.io.json import json_normalize
import folium
from geopy.geocoders import Nominatim 
import requests
CLIENT_ID = "KTCJJ2YZ2143QHEZ2JAQS4FJIO5DLSDO0YN4YBXPMI5NKTEF" # my Foursquare ID
CLIENT_SECRET = "KNG2LO22BPLHN1E3OAHWLYQ5PQBN14XYZMEMAS0CPJEJKOTR" # my Foursquare Secret
VERSION = '20200316'
LIMIT = 10000

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    22.5726, 88.3639,
    30000, 
    LIMIT)

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '6200cc3694de0c5efb44dffe'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc9c62b511f9521982faec7-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_cricket_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d18a941735',
#          'name': 'Cricket Ground',
#          'pluralName': 'Cricket Grounds',
#          'primary': True,
#          'shortName': 'Cricket'}],
#        'id': '4bc9c62b511f9521982faec7',
#        'location': {'address': 'BBD Bagh',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 2300,
#         'formattedAddress': ['BBD Bagh',
#          'Kolkata 700021',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.564541597977065,
#           'lng': 88.34329605102539}],
#         'lat': 22.564541597977065,
#         'lng': 88.34329605102539,
#         'postalCode': '700021',
#         'state': 'West Bengal'},
#        'name': 'Eden Garden',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d4c107ee1ec6dcbad95d475-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4d4c107ee1ec6dcbad95d475',
#        'location': {'address': '15, Jawaharlal Nehru Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 1749,
#         'formattedAddress': ['15, Jawaharlal Nehru Rd',
#          'Kolkata 700013',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.56174943131244,
#           'lng': 88.35159438973265}],
#         'lat': 22.56174943131244,
#         'lng': 88.35159438973265,
#         'postalCode': '700013',
#         'state': 'West Bengal'},
#        'name': 'The Oberoi Grand',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e2c0d7a18a80bb0585fae4d-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4e2c0d7a18a80bb0585fae4d',
#        'location': {'address': 'Hotel Lindsay',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 1854,
#         'formattedAddress': ['Hotel Lindsay',
#          'Kolkata 700087',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55913129083683,
#           'lng': 88.35327973820304}],
#         'lat': 22.55913129083683,
#         'lng': 88.35327973820304,
#         'postalCode': '700087',
#         'state': 'West Bengal'},
#        'name': 'Blue & Beyond',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d43fd7b4e5d370413f4e593-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '4d43fd7b4e5d370413f4e593',
#        'location': {'address': '4/1, Middleton St',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 2972,
#         'formattedAddress': ['4/1, Middleton St',
#          'Kolkata 700071',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.548543210513543,
#           'lng': 88.35135293517806}],
#         'lat': 22.548543210513543,
#         'lng': 88.35135293517806,
#         'postalCode': '700071',
#         'state': 'West Bengal'},
#        'name': 'The Blue Poppy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5085d451e4b0fedcb352298c-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dfe4',
#          'name': 'Indian Sweet Shop',
#          'pluralName': 'Indian Sweet Shops',
#          'primary': True,
#          'shortName': 'Indian Sweets'}],
#        'id': '5085d451e4b0fedcb352298c',
#        'location': {'address': '56, Ramdulal Sarkar St',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 2635,
#         'formattedAddress': ['56, Ramdulal Sarkar St',
#          'Kolkata 700006',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.59603964813232,
#           'lng': 88.36748519805334}],
#         'lat': 22.59603964813232,
#         'lng': 88.36748519805334,
#         'postalCode': '700006',
#         'state': 'West Bengal'},
#        'name': 'Girish Chandra Dey & Nakur Chandra Nandy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50ee506ee4b0f01d13d51008-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/field_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d15f941735',
#          'name': 'Field',
#          'pluralName': 'Fields',
#          'primary': True,
#          'shortName': 'Field'}],
#        'id': '50ee506ee4b0f01d13d51008',
#        'location': {'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3236,
#         'formattedAddress': ['Kolkata', 'West Bengal', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.549906,
#           'lng': 88.344219}],
#         'lat': 22.549906,
#         'lng': 88.344219,
#         'state': 'West Bengal'},
#        'name': 'Maidan',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc788f893bdeee1927d37ae-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4bc788f893bdeee1927d37ae',
#        'location': {'address': 'Ja-1 Sector Iii Salt Lake City',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4264,
#         'formattedAddress': ['Ja-1 Sector Iii Salt Lake City',
#          'Kolkata 700098',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.570357866885754,
#           'lng': 88.40531937782346}],
#         'lat': 22.570357866885754,
#         'lng': 88.40531937782346,
#         'postalCode': '700098',
#         'state': 'West Bengal'},
#        'name': 'Hyatt Regency Kolkata',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-533ada3d498e2b453cfdcb32-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '533ada3d498e2b453cfdcb32',
#        'location': {'address': 'P-183A, C. I. T. Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 2784,
#         'formattedAddress': ['P-183A, C. I. T. Rd',
#          'Kolkata 700054',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.577618905113656,
#           'lng': 88.39043855667114}],
#         'lat': 22.577618905113656,
#         'lng': 88.39043855667114,
#         'postalCode': '700054',
#         'state': 'West Bengal'},
#        'name': 'Cafe Coffee Day',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c284edefe6e2d7f5417533c-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4c284edefe6e2d7f5417533c',
#        'location': {'address': '18, Park St',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 2537,
#         'formattedAddress': ['18, Park St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.552364717378428,
#           'lng': 88.35254430770874}],
#         'lat': 22.552364717378428,
#         'lng': 88.35254430770874,
#         'postalCode': '700016',
#         'state': 'West Bengal'},
#        'name': 'Peter Cat',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c0218258ef2c9b66d9c16fc-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'primary': True,
#          'shortName': 'History Museum'}],
#        'id': '4c0218258ef2c9b66d9c16fc',
#        'location': {'address': "1, Queen's Way",
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3679,
#         'formattedAddress': ["1, Queen's Way",
#          'Kolkata 700071',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.545844129353117,
#           'lng': 88.34289036897952}],
#         'lat': 22.545844129353117,
#         'lng': 88.34289036897952,
#         'postalCode': '700071',
#         'state': 'West Bengal'},
#        'name': 'Victoria Memorial',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dfa2b8aae60f95f8225b9c9-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4dfa2b8aae60f95f8225b9c9',
#        'location': {'address': '54C, Matheswartala Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3829,
#         'formattedAddress': ['54C, Matheswartala Rd',
#          'Kolkata 700046',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.546493181530703,
#           'lng': 88.3881620914969}],
#         'lat': 22.546493181530703,
#         'lng': 88.3881620914969,
#         'postalCode': '700046',
#         'state': 'West Bengal'},
#        'name': 'Big Boss',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cdea62ef8cdb1f7a35e8c12-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4cdea62ef8cdb1f7a35e8c12',
#        'location': {'address': '50/1, Matherswartala Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3861,
#         'formattedAddress': ['50/1, Matherswartala Rd',
#          'Kolkata 700046',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.545592321408858,
#           'lng': 88.3874745703988}],
#         'lat': 22.545592321408858,
#         'lng': 88.3874745703988,
#         'postalCode': '700046',
#         'state': 'West Bengal'},
#        'name': 'Golden Joy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d050f03347da1cd0d012f8f-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dfe1',
#          'name': 'Dhaba',
#          'pluralName': 'Dhabas',
#          'primary': True,
#          'shortName': 'Dhaba'}],
#        'id': '4d050f03347da1cd0d012f8f',
#        'location': {'address': '41/1A, Sarat Bose Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4537,
#         'formattedAddress': ['41/1A, Sarat Bose Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.533096497319534,
#           'lng': 88.35303246974945}],
#         'lat': 22.533096497319534,
#         'lng': 88.35303246974945,
#         'postalCode': '700020',
#         'state': 'West Bengal'},
#        'name': 'Jai Hind Dhaba',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d19f40dbb488cfa6628c1d4-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4d19f40dbb488cfa6628c1d4',
#        'location': {'address': '77/1, Christopher Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3764,
#         'formattedAddress': ['77/1, Christopher Rd',
#          'Kolkata 700046',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.54651846470317,
#           'lng': 88.387213364055}],
#         'lat': 22.54651846470317,
#         'lng': 88.387213364055,
#         'postalCode': '700046',
#         'state': 'West Bengal'},
#        'name': 'Beijing Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-517242db498e0949ba57f2b6-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'primary': True,
#          'shortName': 'History Museum'}],
#        'id': '517242db498e0949ba57f2b6',
#        'location': {'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 1388,
#         'formattedAddress': ['Kolkata', 'West Bengal', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.584401229707083,
#           'lng': 88.35952553409135}],
#         'lat': 22.584401229707083,
#         'lng': 88.35952553409135,
#         'state': 'West Bengal'},
#        'name': 'Jorasankho Thakur-Bari',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bb4f2d60fb7b7132cb9bf8a-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4bb4f2d60fb7b7132cb9bf8a',
#        'location': {'address': 'Jbs Haldane Avenue',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4715,
#         'formattedAddress': ['Jbs Haldane Avenue',
#          'Kolkata 700046',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.544284,
#           'lng': 88.398017}],
#         'lat': 22.544284,
#         'lng': 88.398017,
#         'postalCode': '700046',
#         'state': 'West Bengal'},
#        'name': 'ITC Sonar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d1c6d5a7e10a35dcb13ff82-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dfe1',
#          'name': 'Dhaba',
#          'pluralName': 'Dhabas',
#          'primary': True,
#          'shortName': 'Dhaba'}],
#        'id': '4d1c6d5a7e10a35dcb13ff82',
#        'location': {'address': '10/B, Harish Mukherjee Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4378,
#         'formattedAddress': ['10/B, Harish Mukherjee Rd',
#          'Kolkata 700025',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.537714013534053,
#           'lng': 88.34421978219828}],
#         'lat': 22.537714013534053,
#         'lng': 88.34421978219828,
#         'postalCode': '700025',
#         'state': 'West Bengal'},
#        'name': "Balwant Singh's Eating House",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d4404083616b60c94b5dfc2-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'primary': True,
#          'shortName': 'Cineplex'}],
#        'id': '4d4404083616b60c94b5dfc2',
#        'location': {'address': '89C, Maulana Abdul Kalam Azad Sarani',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'crossStreet': 'at Swabhumi',
#         'distance': 3820,
#         'formattedAddress': ['89C, Maulana Abdul Kalam Azad Sarani (at Swabhumi)',
#          'Kolkata 700054',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.570893097865817,
#           'lng': 88.40102591127794}],
#         'lat': 22.570893097865817,
#         'lng': 88.40102591127794,
#         'postalCode': '700054',
#         'state': 'West Bengal'},
#        'name': 'INOX',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-534fda5e498e8696570687b8-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '534fda5e498e8696570687b8',
#        'location': {'address': 'Quest Mall',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3734,
#         'formattedAddress': ['Quest Mall',
#          'Kolkata 700017',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539091355187338,
#           'lng': 88.36557324255233}],
#         'lat': 22.539091355187338,
#         'lng': 88.36557324255233,
#         'postalCode': '700017',
#         'state': 'West Bengal'},
#        'name': 'Yauatcha',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56042ace498efedb770e3dcc-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'primary': True,
#          'shortName': 'Mall'}],
#        'id': '56042ace498efedb770e3dcc',
#        'location': {'address': '1858/1, Rajdanga Main Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 7103,
#         'formattedAddress': ['1858/1, Rajdanga Main Rd',
#          'Kolkata 700107',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.51482318507145,
#           'lng': 88.3932354886466}],
#         'lat': 22.51482318507145,
#         'lng': 88.3932354886466,
#         'postalCode': '700107',
#         'state': 'West Bengal'},
#        'name': 'Acropolis Mall',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f179ce1e4b035bfa73f9f27-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'primary': True,
#          'shortName': 'Harbor / Marina'}],
#        'id': '4f179ce1e4b035bfa73f9f27',
#        'location': {'address': 'Strand Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3500,
#         'formattedAddress': ['Strand Rd',
#          'Kolkata 700072',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.559267458018144,
#           'lng': 88.33305706140452}],
#         'lat': 22.559267458018144,
#         'lng': 88.33305706140452,
#         'postalCode': '700072',
#         'state': 'West Bengal'},
#        'name': 'Princep Ghat',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d7b9c9e8f89224b06c89326-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4d7b9c9e8f89224b06c89326',
#        'location': {'address': '26/2, Ballygunge Circular Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4922,
#         'formattedAddress': ['26/2, Ballygunge Circular Rd',
#          'Kolkata 700019',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.529016083164827,
#           'lng': 88.35580534635506}],
#         'lat': 22.529016083164827,
#         'lng': 88.35580534635506,
#         'postalCode': '700019',
#         'state': 'West Bengal'},
#        'name': 'Red Hot Chilli Pepper',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5239ee910493e46a092f23c7-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dff4',
#          'name': 'Mughlai Restaurant',
#          'pluralName': 'Mughlai Restaurants',
#          'primary': True,
#          'shortName': 'Mughlai'}],
#        'id': '5239ee910493e46a092f23c7',
#        'location': {'address': '119A, Muzaffar Ahmed St',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'crossStreet': 'Park St',
#         'distance': 2314,
#         'formattedAddress': ['119A, Muzaffar Ahmed St (Park St)',
#          'Kolkata 700016',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.553897023487213,
#           'lng': 88.35406338023041}],
#         'lat': 22.553897023487213,
#         'lng': 88.35406338023041,
#         'postalCode': '700016',
#         'state': 'West Bengal'},
#        'name': 'Arsalan',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-534fda8b498e30c1f4f3ccff-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '534fda8b498e30c1f4f3ccff',
#        'location': {'address': 'Quest Mall',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3724,
#         'formattedAddress': ['Quest Mall',
#          'Kolkata 700017',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539176012738004,
#           'lng': 88.3654510974884}],
#         'lat': 22.539176012738004,
#         'lng': 88.3654510974884,
#         'postalCode': '700017',
#         'state': 'West Bengal'},
#        'name': 'Serafina',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f67492be4b02cbb818e2cf2-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4f67492be4b02cbb818e2cf2',
#        'location': {'address': '211, Acharya Prafulla Chandra Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3403,
#         'formattedAddress': ['211, Acharya Prafulla Chandra Rd',
#          'Kolkata 700004',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.601742094751607,
#           'lng': 88.37392675908148}],
#         'lat': 22.601742094751607,
#         'lng': 88.37392675908148,
#         'postalCode': '700004',
#         'state': 'West Bengal'},
#        'name': 'Golbari',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbf785db083a593d77fa3e9-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'primary': True,
#          'shortName': 'Lounge'}],
#        'id': '4bbf785db083a593d77fa3e9',
#        'location': {'address': 'The Park',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'crossStreet': 'at The Park hotel',
#         'distance': 2325,
#         'formattedAddress': ['The Park (at The Park hotel)',
#          'Kolkata 700016',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55473429407938,
#           'lng': 88.3521798097082}],
#         'lat': 22.55473429407938,
#         'lng': 88.3521798097082,
#         'postalCode': '700016',
#         'state': 'West Bengal'},
#        'name': 'Aqua',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-534a4e4f498e504051fbb385-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '534a4e4f498e504051fbb385',
#        'location': {'address': '5th Floor, Quest Mall',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3769,
#         'formattedAddress': ['5th Floor, Quest Mall',
#          'Kolkata 700017',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53876974957041,
#           'lng': 88.3655321583331}],
#         'lat': 22.53876974957041,
#         'lng': 88.3655321583331,
#         'neighborhood': 'Ballygunge, Kolkata, West Bengal',
#         'postalCode': '700017',
#         'state': 'West Bengal'},
#        'name': 'Bombay Brasserie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd1cf255e0cce72fd05a284-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4bd1cf255e0cce72fd05a284',
#        'location': {'address': '34B, Belvedere Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4970,
#         'formattedAddress': ['34B, Belvedere Rd',
#          'Kolkata 700027',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.537459297849168,
#           'lng': 88.33406559589542}],
#         'lat': 22.537459297849168,
#         'lng': 88.33406559589542,
#         'postalCode': '700027',
#         'state': 'West Bengal'},
#        'name': 'Taj Bengal',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fa614dae4b089a95ad3c4f8-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4fa614dae4b089a95ad3c4f8',
#        'location': {'address': 'New Empire Cinema',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 1841,
#         'formattedAddress': ['New Empire Cinema',
#          'Kolkata 700 013',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.56053424174586,
#           'lng': 88.35164027687136}],
#         'lat': 22.56053424174586,
#         'lng': 88.35164027687136,
#         'postalCode': '700 013',
#         'state': 'West Bengal'},
#        'name': 'The Scoop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c0a0ee8bbc676b0b24449d5-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dff5',
#          'name': 'Bengali Restaurant',
#          'pluralName': 'Bengali Restaurants',
#          'primary': True,
#          'shortName': 'Bengali'}],
#        'id': '4c0a0ee8bbc676b0b24449d5',
#        'location': {'address': 'Forum Mall, 10/3 Elgin Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4022,
#         'formattedAddress': ['Forum Mall, 10/3 Elgin Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53835691442138,
#           'lng': 88.35140625118088}],
#         'lat': 22.53835691442138,
#         'lng': 88.35140625118088,
#         'postalCode': '700020',
#         'state': 'West Bengal'},
#        'name': 'Oh! Calcutta',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5234b18e04932a88f1ff430d-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dff3',
#          'name': 'Awadhi Restaurant',
#          'pluralName': 'Awadhi Restaurants',
#          'primary': True,
#          'shortName': 'Awadhi'}],
#        'id': '5234b18e04932a88f1ff430d',
#        'location': {'address': '34, Karl Marx Sarani',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 5690,
#         'formattedAddress': ['34, Karl Marx Sarani',
#          'Kolkata 700023',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53890350555251,
#           'lng': 88.32227826118468}],
#         'lat': 22.53890350555251,
#         'lng': 88.32227826118468,
#         'postalCode': '700023',
#         'state': 'West Bengal'},
#        'name': 'India Restaurant & Caterer',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '72257354'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-581963bcb1488442b4946d11-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '581963bcb1488442b4946d11',
#        'location': {'address': '4A, J. B. S. Haldane Ave',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4563,
#         'formattedAddress': ['4A, J. B. S. Haldane Ave',
#          'Kolkata 700105',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.54792018921101,
#           'lng': 88.399347558818}],
#         'lat': 22.54792018921101,
#         'lng': 88.399347558818,
#         'postalCode': '700105',
#         'state': 'West Bengal'},
#        'name': 'JW Marriott Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fd7482a7716469f62fb4560-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dfe4',
#          'name': 'Indian Sweet Shop',
#          'pluralName': 'Indian Sweet Shops',
#          'primary': True,
#          'shortName': 'Indian Sweets'}],
#        'id': '4fd7482a7716469f62fb4560',
#        'location': {'address': '2, Paddapukur Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 4725,
#         'formattedAddress': ['2, Paddapukur Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53309675113572,
#           'lng': 88.34708213260403}],
#         'lat': 22.53309675113572,
#         'lng': 88.34708213260403,
#         'postalCode': '700020',
#         'state': 'West Bengal'},
#        'name': 'Balaram Mullick & Radharaman Mullick',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-511b63ace4b00262d57ed073-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dfe4',
#          'name': 'Indian Sweet Shop',
#          'pluralName': 'Indian Sweet Shops',
#          'primary': True,
#          'shortName': 'Indian Sweets'}],
#        'id': '511b63ace4b00262d57ed073',
#        'location': {'address': '48B, Syed Amir Ali Ave',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3813,
#         'formattedAddress': ['48B, Syed Amir Ali Ave',
#          'Kolkata 700017',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53835353486725,
#           'lng': 88.36498975753784}],
#         'lat': 22.53835353486725,
#         'lng': 88.36498975753784,
#         'postalCode': '700017',
#         'state': 'West Bengal'},
#        'name': 'Mithai',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d70225a9aac224bd12337ed-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'primary': True,
#          'shortName': 'Nightclub'}],
#        'id': '4d70225a9aac224bd12337ed',
#        'location': {'address': '31, Shakespeare Sarani',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3136,
#         'formattedAddress': ['31, Shakespeare Sarani',
#          'Kolkata 700017',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.545077960882093,
#           'lng': 88.3573835632132}],
#         'lat': 22.545077960882093,
#         'lng': 88.3573835632132,
#         'postalCode': '700017',
#         'state': 'West Bengal'},
#        'name': 'Nocturne',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cf3afe36c29236adc2472a2-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4cf3afe36c29236adc2472a2',
#        'location': {'address': '2/7, Sarat Bose Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3826,
#         'formattedAddress': ['2/7, Sarat Bose Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539240423448703,
#           'lng': 88.35492074489594}],
#         'lat': 22.539240423448703,
#         'lng': 88.35492074489594,
#         'postalCode': '700020',
#         'state': 'West Bengal'},
#        'name': 'The French Loaf',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d201719d7b0b1f76417129f-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4d201719d7b0b1f76417129f',
#        'location': {'address': '17, Park St',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 2452,
#         'formattedAddress': ['17, Park St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55365167988345,
#           'lng': 88.35173187860914}],
#         'lat': 22.55365167988345,
#         'lng': 88.35173187860914,
#         'postalCode': '700016',
#         'state': 'West Bengal'},
#        'name': 'Oxford Bookstore',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5001966ae4b0444ec20e4135-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5001966ae4b0444ec20e4135',
#        'location': {'address': '222, Acharya Jagadish Chandra Bose Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 3525,
#         'formattedAddress': ['222, Acharya Jagadish Chandra Bose Rd',
#          'Kolkata 700017',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.541217298910773,
#           'lng': 88.35926670939986}],
#         'lat': 22.541217298910773,
#         'lng': 88.35926670939986,
#         'postalCode': '700017',
#         'state': 'West Bengal'},
#        'name': 'The Rouge',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56554d95498e0031a81217a2-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d127951735',
#          'name': 'Arts & Crafts Store',
#          'pluralName': 'Arts & Crafts Stores',
#          'primary': True,
#          'shortName': 'Arts & Crafts'}],
#        'id': '56554d95498e0031a81217a2',
#        'location': {'address': 'Hindustan Pk',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 6118,
#         'formattedAddress': ['Hindustan Pk',
#          'Kolkata 700029',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.517641332811532,
#           'lng': 88.3629834651947}],
#         'lat': 22.517641332811532,
#         'lng': 88.3629834651947,
#         'postalCode': '700029',
#         'state': 'West Bengal'},
#        'name': 'Sienna Store & Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-505b2f9ae4b02d617c540520-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '505b2f9ae4b02d617c540520',
#        'location': {'address': 'Diamond Plaza Mall',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 6900,
#         'formattedAddress': ['Diamond Plaza Mall',
#          'Kolkata 700055',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.615516268438355,
#           'lng': 88.41234683990479}],
#         'lat': 22.615516268438355,
#         'lng': 88.41234683990479,
#         'postalCode': '700055',
#         'state': 'West Bengal'},
#        'name': 'KFC',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d54ed50c6edf04d1af5bea2-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
# ...
#        'id': '515d385be4b0ffeb34f9e956',
#        'location': {'address': '68/1AMOUNT POONAMALLEE ROADNEAR ICICI BANKPORUR,CHENNAI - 600116 PH.NO. 044-22522888/ 22522229/ 22523015/ 16/ 17/ 18.',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 10046,
#         'formattedAddress': ['68/1AMOUNT POONAMALLEE ROADNEAR ICICI BANKPORUR,CHENNAI - 600116 PH.NO. 044-22522888/ 22522229/ 22523015/ 16/ 17/ 18.',
#          'Kolkata 700157',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display', 'lat': 22.617, 'lng': 88.449}],
#         'lat': 22.617,
#         'lng': 88.449,
#         'postalCode': '700157',
#         'state': 'West Bengal'},
#        'name': "Domino's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d6fa1760187236a95b89eba-72',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4d6fa1760187236a95b89eba',
#        'location': {'address': 'R. D. Mall',
#         'cc': 'IN',
#         'city': 'Hāora',
#         'country': 'India',
#         'distance': 5780,
#         'formattedAddress': ['R. D. Mall',
#          'Hāora 711204',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.62280531191644,
#           'lng': 88.34954023361206}],
#         'lat': 22.62280531191644,
#         'lng': 88.34954023361206,
#         'postalCode': '711204',
#         'state': 'West Bengal'},
#        'name': "Domino's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ca6f8eb8882199c1d8d43d4-73',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'primary': True,
#          'shortName': 'Snacks'}],
#        'id': '4ca6f8eb8882199c1d8d43d4',
#        'location': {'address': 'VIP Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'crossStreet': 'Kaji Nazrul Islam Avenue',
#         'distance': 9404,
#         'formattedAddress': ['VIP Rd (Kaji Nazrul Islam Avenue)',
#          'Kolkata 700136',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.62809358799676,
#           'lng': 88.43290328979492}],
#         'lat': 22.62809358799676,
#         'lng': 88.43290328979492,
#         'postalCode': '700136',
#         'state': 'West Bengal'},
#        'name': "Haldiram's Prabhuji",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5227295211d2b439c7015093-74',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'id': '5227295211d2b439c7015093',
#        'location': {'address': 'Raghunathpur',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'crossStreet': 'VIP Road, Beside Bazaar Kolkata',
#         'distance': 8659,
#         'formattedAddress': ['Raghunathpur (VIP Road, Beside Bazaar Kolkata)',
#          'Kolkata 700059',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.61836455157655,
#           'lng': 88.43203268807126}],
#         'lat': 22.61836455157655,
#         'lng': 88.43203268807126,
#         'postalCode': '700059',
#         'state': 'West Bengal'},
#        'name': 'KFC',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5083f3f2498e54db9e6744de-75',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '5083f3f2498e54db9e6744de',
#        'location': {'address': 'N/24, Jessore Rd',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 18752,
#         'formattedAddress': ['N/24, Jessore Rd',
#          'Kolkata 700124',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.707036994037505,
#           'lng': 88.47388744354248}],
#         'lat': 22.707036994037505,
#         'lng': 88.47388744354248,
#         'postalCode': '700124',
#         'state': 'West Bengal'},
#        'name': "Domino's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5195a251498e304d66cc77f9-76',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '5195a251498e304d66cc77f9',
#        'location': {'address': 'Netaji Subhash Chandra Bose International Airport',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 11005,
#         'formattedAddress': ['Netaji Subhash Chandra Bose International Airport',
#          'Kolkata 700052',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.642496580970697,
#           'lng': 88.43964298001526}],
#         'lat': 22.642496580970697,
#         'lng': 88.43964298001526,
#         'postalCode': '700052',
#         'state': 'West Bengal'},
#        'name': 'Chicago Crust',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bfa81d38d30d13ad1a80318-77',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'primary': True,
#          'shortName': 'Food Court'}],
#        'id': '4bfa81d38d30d13ad1a80318',
#        'location': {'address': 'City Center 2',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 10504,
#         'formattedAddress': ['City Center 2',
#          'Kolkata 700157',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.622926941824232,
#           'lng': 88.45036041516343}],
#         'lat': 22.622926941824232,
#         'lng': 88.45036041516343,
#         'postalCode': '700157',
#         'state': 'West Bengal'},
#        'name': 'HangOut',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bfa7f2c5ec320a14aaf8bd3-78',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4bfa7f2c5ec320a14aaf8bd3',
#        'location': {'address': 'City Centre 2',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'crossStreet': 'Rajarhat',
#         'distance': 10505,
#         'formattedAddress': ['City Centre 2 (Rajarhat)',
#          'Kolkata 700157',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.622968098515937,
#           'lng': 88.4503497700007}],
#         'lat': 22.622968098515937,
#         'lng': 88.4503497700007,
#         'postalCode': '700157',
#         'state': 'West Bengal'},
#        'name': 'KFC',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52b509cd498e85878f0eba35-79',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d57352f',
#          'name': 'Airport Service',
#          'pluralName': 'Airport Services',
#          'primary': True,
#          'shortName': 'Airport Service'}],
#        'id': '52b509cd498e85878f0eba35',
#        'location': {'address': 'Netaji Subhash Chandra Bose International Airport',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 10795,
#         'formattedAddress': ['Netaji Subhash Chandra Bose International Airport',
#          'Kolkata 700052',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.64060121859067,
#           'lng': 88.43879557464575}],
#         'lat': 22.64060121859067,
#         'lng': 88.43879557464575,
#         'postalCode': '700052',
#         'state': 'West Bengal'},
#        'name': 'Immigration Check',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-502c8532e4b06ef10c7619bb-80',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'id': '5453de49498eade8af355881',
#          'name': 'Business Service',
#          'pluralName': 'Business Services',
#          'primary': True,
#          'shortName': 'Business Services'}],
#        'id': '502c8532e4b06ef10c7619bb',
#        'location': {'address': 'Unitech Infospace',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 12271,
#         'formattedAddress': ['Unitech Infospace',
#          'Kolkata 700156',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.5747825,
#           'lng': 88.4832572}],
#         'lat': 22.5747825,
#         'lng': 88.4832572,
#         'postalCode': '700156',
#         'state': 'West Bengal'},
#        'name': 'Accenture',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5486a408498e2f6041f8d388-81',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b36',
#          'name': 'IT Services',
#          'pluralName': 'IT Services',
#          'primary': True,
#          'shortName': 'IT Services'}],
#        'id': '5486a408498e2f6041f8d388',
#        'location': {'address': 'International Finalcial Hub(CBD), Newtown',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 12604,
#         'formattedAddress': ['International Finalcial Hub(CBD), Newtown',
#          'Kolkata 700156',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.58004921017817,
#           'lng': 88.48625969610143}],
#         'lat': 22.58004921017817,
#         'lng': 88.48625969610143,
#         'postalCode': '700156',
#         'state': 'West Bengal'},
#        'name': 'TCS, Gitanjali Park',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5303a0da11d2eac30b63f1af-82',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b56',
#          'name': 'ATM',
#          'pluralName': 'ATMs',
#          'primary': True,
#          'shortName': 'ATM'}],
#        'id': '5303a0da11d2eac30b63f1af',
#        'location': {'address': 'Village - Barijahatty, P. O - Chanditala',
#         'cc': 'IN',
#         'city': 'Dhankuni',
#         'country': 'India',
#         'distance': 16606,
#         'formattedAddress': ['Village - Barijahatty, P. O - Chanditala',
#          'Dhankuni 712311',
#          'West Bengal',
#          'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.690559,
#           'lng': 88.264958}],
#         'lat': 22.690559,
#         'lng': 88.264958,
#         'postalCode': '712311',
#         'state': 'West Bengal'},
#        'name': 'HDFC Bank ATM',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f4472cce4b0a28181ae2684-83',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d129951735',
#          'name': 'Train Station',
#          'pluralName': 'Train Stations',
#          'primary': True,
#          'shortName': 'Train Station'}],
#        'id': '4f4472cce4b0a28181ae2684',
#        'location': {'cc': 'IN',
#         'city': 'Kolkata',
#         'country': 'India',
#         'distance': 19159,
#         'formattedAddress': ['Kolkata', 'West Bengal', 'India'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.720510352177616,
#           'lng': 88.26854217736594}],
#         'lat': 22.720510352177616,
#         'lng': 88.26854217736594,
#         'state': 'West Bengal'},
#        'name': 'Janai Road Station',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Kolkata',
#   'headerLocation': 'Kolkata',
#   'headerLocationGranularity': 'city',
#   'queryRefinements': {'refinements': [{'query': 'Food'},
#     {'query': 'Nightlife'},
#     {'query': 'Coffee'},
#     {'query': 'Shops'},
#     {'query': 'Arts'},
#     {'query': 'Outdoors'}],
#    'target': {'params': {'ll': '22.572600,88.363900', 'radius': '30000'},
#     'type': 'path',
#     'url': '/venue/explore'}},
#   'suggestedBounds': {'ne': {'lat': 22.842600270000272,
#     'lng': 88.65575394414539},
#    'sw': {'lat': 22.30259972999973, 'lng': 88.07204605585461}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 84}}

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
nearby_venues
# Out:
#                          referralId  ...  venue.venuePage.id
# 0    e-0-4bc9c62b511f9521982faec7-0  ...                 NaN
# 1    e-0-4d4c107ee1ec6dcbad95d475-1  ...                 NaN
# 2    e-0-4e2c0d7a18a80bb0585fae4d-2  ...                 NaN
# 3    e-0-4d43fd7b4e5d370413f4e593-3  ...                 NaN
# 4    e-0-5085d451e4b0fedcb352298c-4  ...                 NaN
# ..                              ...  ...                 ...
# 79  e-0-52b509cd498e85878f0eba35-79  ...                 NaN
# 80  e-0-502c8532e4b06ef10c7619bb-80  ...                 NaN
# 81  e-0-5486a408498e2f6041f8d388-81  ...                 NaN
# 82  e-0-5303a0da11d2eac30b63f1af-82  ...                 NaN
# 83  e-0-4f4472cce4b0a28181ae2684-83  ...                 NaN
#
# [84 rows x 22 columns]

# %%
nearby_venues
# Out:
#                          referralId  ...  venue.venuePage.id
# 0    e-0-4bc9c62b511f9521982faec7-0  ...                 NaN
# 1    e-0-4d4c107ee1ec6dcbad95d475-1  ...                 NaN
# 2    e-0-4e2c0d7a18a80bb0585fae4d-2  ...                 NaN
# 3    e-0-4d43fd7b4e5d370413f4e593-3  ...                 NaN
# 4    e-0-5085d451e4b0fedcb352298c-4  ...                 NaN
# ..                              ...  ...                 ...
# 79  e-0-52b509cd498e85878f0eba35-79  ...                 NaN
# 80  e-0-502c8532e4b06ef10c7619bb-80  ...                 NaN
# 81  e-0-5486a408498e2f6041f8d388-81  ...                 NaN
# 82  e-0-5303a0da11d2eac30b63f1af-82  ...                 NaN
# 83  e-0-4f4472cce4b0a28181ae2684-83  ...                 NaN
#
# [84 rows x 22 columns]

# %% [markdown]
# ## Adding two more Columns Restaurant and Others
#
#
# 1.   Restaurant: Number of Restaurant in the radius of 20 km
# 2.   others:Number of Gyms, Parks,etc in the radius of 20 km

# %%
resta=[]
oth=[]
for lat,long in zip(nearby_venues['venue.location.lat'],nearby_venues['venue.location.lng']):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
      CLIENT_ID, 
      CLIENT_SECRET, 
      VERSION, 
      lat,long,
      1000, 
      100)
    res = requests.get(url).json()
    venue = res['response']['groups'][0]['items']
    nearby_venue = json_normalize(venue)
    df=nearby_venue['venue.categories']

    g=[]
    for i in range(0,df.size):
      g.append(df[i][0]['icon']['prefix'].find('food'))
    co=0
    for i in g:
      if i>1:
        co+=1
    resta.append(co)
    oth.append(len(g)-co)

nearby_venues['restaurant']=resta
nearby_venues['others']=oth
nearby_venues
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   del sys.path[0]
#                          referralId  reasons.count  ... restaurant others
# 0    e-0-4bc9c62b511f9521982faec7-0              0  ...          9     14
# 1    e-0-4d4c107ee1ec6dcbad95d475-1              0  ...         36     23
# 2    e-0-4e2c0d7a18a80bb0585fae4d-2              0  ...         47     24
# 3    e-0-4d43fd7b4e5d370413f4e593-3              0  ...         48     31
# 4    e-0-5085d451e4b0fedcb352298c-4              0  ...          7      7
# ..                              ...            ...  ...        ...    ...
# 79  e-0-52b509cd498e85878f0eba35-79              0  ...         10      9
# 80  e-0-502c8532e4b06ef10c7619bb-80              0  ...          1      6
# 81  e-0-5486a408498e2f6041f8d388-81              0  ...          1      5
# 82  e-0-5303a0da11d2eac30b63f1af-82              0  ...          0      2
# 83  e-0-4f4472cce4b0a28181ae2684-83              0  ...          0      2
#
# [84 rows x 24 columns]

# %% [markdown]
# ## Changing the Column Name

# %%
lat=nearby_venues['venue.location.lat']
long=nearby_venues['venue.location.lng']

# %% [markdown]
# ## Install the minisom library using pip
#
# MiniSom is a minimalistic and Numpy based implementation of the Self Organizing Maps (SOM). SOM is a type of Artificial Neural Network able to convert complex, nonlinear statistical relationships between high-dimensional data items into simple geometric relationships on a low-dimensional display. Minisom is designed to allow researchers to easily build on top of it and to give students the ability to quickly grasp its details.

# %%
pip install minisom
# Out:
# Requirement already satisfied: minisom in /usr/local/lib/python3.7/dist-packages (2.2.8)

# %% [markdown]
# ## Run K Means clustering on the dataset, with the optimal K value using Elbow Method
#
# A fundamental step for any unsupervised algorithm is to determine the optimal number of clusters into which the data may be clustered. The Elbow Method is one of the most popular methods to determine this optimal value of k.

# %%
f=['venue.location.lat','venue.location.lng']
X = nearby_venues[f]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i 
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()

# %%
city = "Kolkata"
## get location
locator = geopy.geocoders.Nominatim(user_agent="MyCoder")
location = locator.geocode(city)
print(location)
## keep latitude and longitude only
location = [location.latitude, location.longitude]
print("[lat, long]:", location)
# Out:
# Kolkata, West Bengal, India
# [lat, long]: [22.5414185, 88.35769124388872]

# %%
nearby_venues.head()
# Out:
#                        referralId  reasons.count  ... restaurant others
# 0  e-0-4bc9c62b511f9521982faec7-0              0  ...          9     14
# 1  e-0-4d4c107ee1ec6dcbad95d475-1              0  ...         36     23
# 2  e-0-4e2c0d7a18a80bb0585fae4d-2              0  ...         47     24
# 3  e-0-4d43fd7b4e5d370413f4e593-3              0  ...         48     31
# 4  e-0-5085d451e4b0fedcb352298c-4              0  ...          7      7
#
# [5 rows x 24 columns]

# %%
nearby_venues.columns
# Out:
# Index(['referralId', 'reasons.count', 'reasons.items', 'venue.id',
#        'venue.name', 'venue.location.address', 'venue.location.lat',
#        'venue.location.lng', 'venue.location.labeledLatLngs',
#        'venue.location.distance', 'venue.location.postalCode',
#        'venue.location.cc', 'venue.location.city', 'venue.location.state',
#        'venue.location.country', 'venue.location.formattedAddress',
#        'venue.categories', 'venue.photos.count', 'venue.photos.groups',
#        'venue.location.crossStreet', 'venue.location.neighborhood',
#        'venue.venuePage.id', 'restaurant', 'others'],
#       dtype='object')

# %% [markdown]
# ##Data Cleaning Process for Extracting Necessary Columns in the Dataset

# %%
n=nearby_venues.drop(['referralId', 'reasons.count', 'reasons.items', 'venue.id',
       'venue.name', 
       'venue.location.labeledLatLngs', 'venue.location.distance',
       'venue.location.cc', 
       'venue.categories', 'venue.photos.count', 'venue.photos.groups',
       'venue.location.crossStreet', 'venue.location.address','venue.location.city',
       'venue.location.state', 'venue.location.crossStreet',
       'venue.location.neighborhood',	'venue.venuePage.id',
       'venue.location.postalCode','venue.location.country'],axis=1)

# %%
n.columns
# Out:
# Index(['venue.location.lat', 'venue.location.lng',
#        'venue.location.formattedAddress', 'restaurant', 'others'],
#       dtype='object')

# %% [markdown]
# ##New Dataset

# %%
n
# Out:
#     venue.location.lat  venue.location.lng  ... restaurant  others
# 0            22.564542           88.343296  ...          9      14
# 1            22.561749           88.351594  ...         36      23
# 2            22.559131           88.353280  ...         47      24
# 3            22.548543           88.351353  ...         48      31
# 4            22.596040           88.367485  ...          7       7
# ..                 ...                 ...  ...        ...     ...
# 79           22.640601           88.438796  ...         10       9
# 80           22.574783           88.483257  ...          1       6
# 81           22.580049           88.486260  ...          1       5
# 82           22.690559           88.264958  ...          0       2
# 83           22.720510           88.268542  ...          0       2
#
# [84 rows x 5 columns]

# %% [markdown]
# ## Dropping Nan Values from Dataset

# %%
n=n.dropna()
n = n.rename(columns={'venue.location.lat': 'lat', 'venue.location.lng': 'long'})
n
# Out:
#           lat       long  ... restaurant  others
# 0   22.564542  88.343296  ...          9      14
# 1   22.561749  88.351594  ...         36      23
# 2   22.559131  88.353280  ...         47      24
# 3   22.548543  88.351353  ...         48      31
# 4   22.596040  88.367485  ...          7       7
# ..        ...        ...  ...        ...     ...
# 79  22.640601  88.438796  ...         10       9
# 80  22.574783  88.483257  ...          1       6
# 81  22.580049  88.486260  ...          1       5
# 82  22.690559  88.264958  ...          0       2
# 83  22.720510  88.268542  ...          0       2
#
# [84 rows x 5 columns]

# %% [markdown]
# ###Convert Every Row of Column ***'venue.location.formattedAddress'*** from List to String

# %%
n['venue.location.formattedAddress']
# Out:
# 0        [BBD Bagh, Kolkata 700021, West Bengal, India]
# 1     [15, Jawaharlal Nehru Rd, Kolkata 700013, West...
# 2     [Hotel Lindsay, Kolkata 700087, West Bengal, I...
# 3     [4/1, Middleton St, Kolkata 700071, West Benga...
# 4     [56, Ramdulal Sarkar St, Kolkata 700006, West ...
#                             ...
# 79    [Netaji Subhash Chandra Bose International Air...
# 80    [Unitech Infospace, Kolkata 700156, West Benga...
# 81    [International Finalcial Hub(CBD), Newtown, Ko...
# 82    [Village - Barijahatty, P. O - Chanditala, Dha...
# 83                        [Kolkata, West Bengal, India]
# Name: venue.location.formattedAddress, Length: 84, dtype: object

# %%
spec_chars = ["[","]"]
for char in spec_chars:
  n['venue.location.formattedAddress'] = n['venue.location.formattedAddress'].astype(str).str.replace(char, ' ')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
n
# Out:
#           lat       long  ... restaurant  others
# 0   22.564542  88.343296  ...          9      14
# 1   22.561749  88.351594  ...         36      23
# 2   22.559131  88.353280  ...         47      24
# 3   22.548543  88.351353  ...         48      31
# 4   22.596040  88.367485  ...          7       7
# ..        ...        ...  ...        ...     ...
# 79  22.640601  88.438796  ...         10       9
# 80  22.574783  88.483257  ...          1       6
# 81  22.580049  88.486260  ...          1       5
# 82  22.690559  88.264958  ...          0       2
# 83  22.720510  88.268542  ...          0       2
#
# [84 rows x 5 columns]

# %% [markdown]
# #Plot the clustered locations on a map

# %%
x, y = "lat", "long"
color = "restaurant"
size = "others"
popup = "venue.location.formattedAddress"
data = n.copy()

## create color column
lst_colors=["red","green","orange"]
lst_elements = sorted(list(n[color].unique()))

## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)

## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=11)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]],popup=row[popup],
           radius=row["size"]).add_to(map_), axis=1)
## add html legend


## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_57061a08b94a4fcead06a580650b9bb9%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_57061a08b94a4fcead06a580650b9bb9%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_57061a08b94a4fcead06a580650b9bb9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_57061a08b94a4fcead06a580650b9bb9%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B22.5414185%2C%2088.35769124388872%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_315e475ef2024f8db8549a563b962d19%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_all/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution ...

# %%
X = n[["lat","long"]]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()

# %%
k = 6
model = cluster.KMeans(n_clusters=k, init='k-means++')
X = n[["lat","long"]]
## clustering
dtf_X = X.copy()
dtf_X["cluster"] = model.fit_predict(X)
## find real centroids
closest, distances = scipy.cluster.vq.vq(model.cluster_centers_, 
                     dtf_X.drop("cluster", axis=1).values)
dtf_X["centroids"] = 0
for i in closest:
    dtf_X["centroids"].iloc[i] = 1
## add clustering info to the original dataset
n[["cluster","centroids"]] = dtf_X[["cluster","centroids"]]
n
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#           lat       long  ... cluster  centroids
# 0   22.564542  88.343296  ...       4          0
# 1   22.561749  88.351594  ...       4          0
# 2   22.559131  88.353280  ...       4          0
# 3   22.548543  88.351353  ...       4          0
# 4   22.596040  88.367485  ...       5          0
# ..        ...        ...  ...     ...        ...
# 79  22.640601  88.438796  ...       3          0
# 80  22.574783  88.483257  ...       0          0
# 81  22.580049  88.486260  ...       0          1
# 82  22.690559  88.264958  ...       2          1
# 83  22.720510  88.268542  ...       2          0
#
# [84 rows x 7 columns]

# %%
## plot
fig, ax = plt.subplots()
sns.scatterplot(x="lat", y="long", data=n, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief", ax=ax).set_title('Clustering (k='+str(k)+')')
th_centroids = model.cluster_centers_
ax.scatter(th_centroids[:,0], th_centroids[:,1], s=50, c='black', 
           marker="x")

# %%
model = cluster.AffinityPropagation()

# %%
k = n["cluster"].nunique()
sns.scatterplot(x="lat", y="long", data=n, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief").set_title('Clustering (k='+str(k)+')')
# Out:
# Text(0.5, 1.0, 'Clustering (k=6)')

# %%
x, y = "lat", "long"
color = "cluster"
size = "restaurant"
popup = "venue.location.formattedAddress"
marker = "centroids"
data = n.copy()
## create color column
lst_elements = sorted(list(n[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])
## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)
## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=11)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], 
           color=row["color"], fill=True,popup=row[popup],
           radius=row["size"]).add_to(map_), axis=1)
## add html legend
legend_html = """<div style="position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;">&nbsp;<b>"""+color+""":</b><br>"""
for i in lst_elements:
     legend_html = legend_html+"""&nbsp;<i class="fa fa-circle 
     fa-1x" style="color:"""+lst_colors[lst_elements.index(i)]+"""">
     </i>&nbsp;"""+str(i)+"""<br>"""
legend_html = legend_html+"""</div>"""
map_.get_root().html.add_child(folium.Element(legend_html))
## add centroids marker
lst_elements = sorted(list(n[marker].unique()))
data[data[marker]==1].apply(lambda row: 
           folium.Marker(location=[row[x],row[y]], 
           draggable=False,  popup=row[popup] ,       
           icon=folium.Icon(color="black")).add_to(map_), axis=1)
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_a0e786a670174bd29f8dd636c81497a3%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%3Cdiv%20style%3D%22position%3Afixed%3B%20bottom%3A10px%3B%20left%3A10px%3B%20border%3A2px%20solid%20black%3B%20z-index%3A9999%3B%20font-size%3A14px%3B%22%3E%26nbsp%3B%3Cb%3Ecluster%3A%3C/b%3E%3Cbr%3E%26nbsp%3B%3Ci%20class%3D%22fa%20fa-circle%20%0A%20%20%20%20%20fa-1x%22%20style%3D%22color%3A%230FD224%22%3E%0A%20%20%20%20%20%3C/i%3E%26nbsp%3B0%3Cbr%3E%26nbsp%3B%3Ci%20class%3D%22fa%20fa-circle%20%0A%20%20%20%20%20fa-1x%22%20style%3D%22color%3A%2372859F%22%3E%0A%20%20%20%20%20%3C/i%3E%26nbsp%3B1%3Cbr%3E%26nbsp%3B%3Ci%20class%3D%22fa%20fa-circle%20%0A%20%20%20%20%20fa-1x%22%20style%3D%22color%3A%23EC49EB%22%3E%0A%20%20%20%20%20%3C/i%3E%26nbsp%3B2%3Cbr%3E%26nbsp%3B%3Ci%20class%3D%22fa%20fa-circle%20%0A%20%20%20%20%20fa-1x%22%20style%3D%22color%3A%231AC7D9%22%3E%0A%20%20%20%20%20%3C/i%3E%26nbsp%3B3%3Cbr%3E%26nbsp%3B%3Ci%20class%3D%22fa%20fa-circle%20%0A%20%20%20%20%20fa-1x%22%20style%3D%22color%3A%23C8DFBA%22%3E%0A%20%20%20%20%20%3C/i%3E%26nbsp%3B4%3Cbr%3E%26nbsp%3B%3Ci%20class%3D%22fa%20fa-circle%20%0A%20%20%20%20%20fa-1x%22%20style%3D%22color%3A%23227F96%22%3E%0A%20%20%20%20%20%3C/i%3E%26nbsp%3B5%3Cbr%3E%3C/div%3E%0A%20% ...

# %% [markdown]
# ## ***Thankyou***
